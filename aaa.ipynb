# %%
import pandas as pd

# %%
df = pd.read_csv('data/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
aux = df[['cast', 'title']]
aux = aux.loc[aux['cast'] != ', ']
aux.dropna(inplace=True)    
aux.cast = aux.cast.str.strip(', ')

# %%
aux.rename(columns={'cast': 'people'}, inplace=True)

# %%
# actor_film = {}
# film_actor = {}
# main_actor = "Kevin Bacon"
relation_graph = {'Kevin Bacon'}
final_relation_graph = {'Kevin Bacon'}
final_actor = 'Asfora'
def BT(relation_graph,max_size):
    size = len(relation_graph)
    if size == max_size:
        return
    aux = df.loc[df['people'].str.find(relation_graph[size-1]) != -1]
    for movie in aux['title'].to_list():
        aux2 = df.loc[df['title'].str.find(movie) != -1]
        for actor in aux2['people'].to_list():
            relation_graph.append(movie)
            relation_graph.append(actor)
            if actor == final_actor and (len(final_relation_graph)==1 or size<=len(final_relation_graph)):
                final_relation_graph=relation_graph
                return
            BT(relation_graph,max_size)
            relation_graph.pop()
            relation_graph.pop()



# def get_actor_film(actor_film: dict, film_actor: dict, i, lim, df):
#     if i == lim:
#         return
#     if i == 0:
#         aux = df.loc[df['people'].str.find(main_actor) != -1]
#         actor_film[main_actor] = aux['title'].to_list()
#         for element in actor_film[main_actor]:
#             aux = aux.loc[aux['title'] == element]
#             film_actor[element] = list(aux['people'])
#     for actors in film_actor.values():
#         for actor in actors:
#             if actor in actor_film:
#                 continue
#             aux = df.loc[df['people'].str.find(actor) != -1]
#             actor_film[actor] = aux['title'].to_list()
#     for movies in actor_film[actor]:
#         for movie in movies:
#             aux= df.loc[aux['title'] == movie]
#             film_actor[movie] = aux['people'].str.split(', ')
#     get_actor_film(actor_film, film_actor, i+1, lim, df)
# get_actor_film(actor_film, film_actor, 0, 2, aux)
# print(actor_film)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a>             film_actor[movie] = aux['people'].str.split(', ')
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a>     get_actor_film(actor_film, film_actor, i+1, lim, df)
# ---> <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> get_actor_film(actor_film, film_actor, 0, 2, aux)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> print(actor_film)
#
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 2
# ...
