# %%
import pandas as pd

# %%
df = pd.read_csv('data/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
aux = df[['cast', 'title']]
aux = aux.loc[aux['cast'] != ', ']
aux.dropna(inplace=True)    
aux.cast = aux.cast.str.strip(', ')

# %%
aux.rename(columns={'cast': 'people'}, inplace=True)

# %%
# actor_film = {}
# film_actor = {}
# main_actor = "Kevin Bacon"
relation_graph = ['Kevin Bacon']
final_relation_graph = ['Kevin Bacon']
final_actor = 'Peyton Reed'
def BT(relation_graph,max_size, df: pd.DataFrame):
    global final_relation_graph
    global final_actor
    
    size = len(relation_graph)
    if size == max_size:
        return
    aux = df.loc[df['people'].str.find(relation_graph[size-1]) != -1]
    for movie in aux['title'].to_list():
        aux2 = df.loc[df['title'].str.find(movie) != -1]
        for actors in aux2['people'].values:
            for actor in actors.split(', '):
                relation_graph.append(movie)
                relation_graph.append(actor)
                if actor == final_actor and (len(final_relation_graph)==1 or size<=len(final_relation_graph)):
                    final_relation_graph=relation_graph
                    print(final_relation_graph)
                    return
                BT(relation_graph,max_size, df)
                relation_graph.pop()
                relation_graph.pop()

BT(relation_graph, 7, aux)
final_relation_graph
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a>                 relation_graph.pop()
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a>                 relation_graph.pop()
# ---> <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a> BT(relation_graph, 7, aux)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a> final_relation_graph
#
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=22'>23</a>     print(final_relation_graph)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=23'>24</a>     return
# ---> <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a> BT(relation_graph,max_size, df)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a> relation_graph.pop()
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a> relation_graph.pop()
#
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=22'>23</a>     print(final_relation_graph)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=23'>24</a>     return
# ---> <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a> BT(relation_graph,max_size, df)
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a> relation_graph.pop()
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a> relation_graph.pop()
#
# /home/fabricio/Documents/programs/ime/labprog/aaa.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a> aux = df.loc[df['people'].str.find(relation_graph[size-1]) != -1]
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> for movie in aux['title'].to_list():
# ---> <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a>     aux2 = df.loc[df['title'].str.find(movie) != -1]
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=16'>17</a>     for actors in aux2['people'].values:
#      <a href='vscode-notebook-cell:/home/fabricio/Documents/programs/ime/labprog/aaa.ipynb#X23sZmlsZQ%3D%3D?line=17'>18</a>         for actor in actors.split(', '):
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/accessor.py:2765, in StringMethods.find(self, sub, start, end)
#    2762     msg = f"expected a string object, not {type(sub).__name__}"
#    2763     raise TypeError(msg)
# -> 2765 result = self._data.array._str_find(sub, start, end)
#    2766 return self._wrap_result(result, returns_string=False)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/object_array.py:226, in ObjectStringArrayMixin._str_find(self, sub, start, end)
#     225 def _str_find(self, sub, start=0, end=None):
# --> 226     return self._str_find_(sub, start, end, side="left")
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/object_array.py:243, in ObjectStringArrayMixin._str_find_(self, sub, start, end, side)
#     241 else:
#     242     f = lambda x: getattr(x, method)(sub, start, end)
# --> 243 return self._str_map(f, dtype="int64")
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/object_array.py:71, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      69 map_convert = convert and not np.all(mask)
#      70 try:
# ---> 71     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      72 except (TypeError, AttributeError) as err:
#      73     # Reraise the exception if callable `f` got wrong number of args.
#      74     # The user may want to be warned by this, instead of getting NaN
#      75     p_err = (
#      76         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      77         r"(?(3)required )positional arguments?"
#      78     )
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2876, in pandas._libs.lib.map_infer_mask()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/strings/object_array.py:240, in ObjectStringArrayMixin._str_find_.<locals>.<lambda>(x)
#     237     raise ValueError("Invalid side")
#     239 if end is None:
# --> 240     f = lambda x: getattr(x, method)(sub, start)
#     241 else:
#     242     f = lambda x: getattr(x, method)(sub, start, end)
#
# KeyboardInterrupt:
